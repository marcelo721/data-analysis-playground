# %%
#importando as bibliotecas para resolução do exercicio
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as srn

# %%
#próximo passo é carregar os dados 
base = pd.read_csv('dados.csv', sep=';')
base.shape
# Out:
# (187, 4)

# %%
base.head()
# Out:
#    CODIGO               MUNICIPIO       PIB  VALOREMPENHO
# 0     106   SANTANA DO LIVRAMENTO  12240.76    1088666.10
# 1     113            SANTO ANGELO  16575.82     800669.92
# 2     118  SAO FRANCISCO DE ASSIS  12037.61     466122.80
# 3      13         CACAPAVA DO SUL  13674.54     485535.86
# 4     120             SAO GABRIEL  19912.38     533719.86

# %%
srn.histplot(base.PIB, kde=True, bins= 10).set_title('PIB')
# Out:
# Text(0.5, 1.0, 'PIB')

# %%
srn.histplot(base.VALOREMPENHO, kde=True, bins=10).set_title('Empenho')
# Out:
# Text(0.5, 1.0, 'Empenho')

# %%
agrupado = base.sort_values('PIB').head(10)
agrupado = agrupado.iloc[:,[1,3]]
agrupado
# Out:
#                MUNICIPIO  VALOREMPENHO
# 88             REDENTORA      60134.00
# 11       AMARAL FERRADOR     235327.02
# 15   ENCRUZILHADA DO SUL     200738.61
# 66      SENTINELA DO SUL      92380.20
# 89    SAO VALERIO DO SUL      67638.25
# 6               PIRATINI     315884.50
# 56                  MATA     107740.90
# 37  SANTANA DA BOA VISTA     139594.29
# 16               CANGUCU     205741.65
# 47             JAQUIRANA     129434.42

# %%
agrupado.plot.bar(x= 'MUNICIPIO', y='VALOREMPENHO', color='gray')
# Out:
# <Axes: xlabel='MUNICIPIO'>
